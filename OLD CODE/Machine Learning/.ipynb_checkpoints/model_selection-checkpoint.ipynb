# %%
import pandas as pd

# %%
df = pd.read_csv('dev.csv')
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#      Energy      Corr   Diss_sim   Homogen    Contrast   Energy2     Corr2  \
# 0  0.583967  0.975496   9.404243  0.800701  616.918643  0.537251  0.836165
# 1  0.509047  0.967128  12.441789  0.753983  879.054381  0.442463  0.781184
# 2  0.547644  0.974732  10.141636  0.778776  631.485478  0.495706  0.823576
# 3  0.559575  0.975192   9.733793  0.800335  658.681863  0.511135  0.834312
# 4  0.675394  0.969754   8.110708  0.851848  616.763526  0.637400  0.807739
#
#    Diss_sim2  Homogen2    Contrast2  ...  Corr4  Diss_sim4  Homogen4  \
# 0  27.847425  0.714304  4132.026649  ...      1          0         1
# 1  37.348783  0.644560  5857.093812  ...      1          0         1
# 2  30.401309  0.684403  4413.912024  ...      1          0         1
# 3  28.922338  0.713047  4394.650259  ...      1          0         1
# 4  24.283581  0.781797  3936.207958  ...      1          0         1
#
#    Contrast4   Energy5  Corr5  Diss_sim5  Homogen5  Contrast5  languages
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train , x_test , y_train , y_test = train_test_split(X,y,test_size=.30,random_state=43)

# %%
X_train.head(5)
# Out:
#         Energy      Corr  Diss_sim   Homogen    Contrast   Energy2     Corr2  \
# 417   0.640648  0.987952  6.023943  0.822557  262.974464  0.611589  0.906224
# 368   0.538856  0.994183  4.623254  0.830261  163.224050  0.513123  0.953511
# 1663  0.606278  0.977661  8.876930  0.788106  512.470772  0.565336  0.841921
# 703   0.554922  0.983324  8.192356  0.798420  441.663220  0.511119  0.877900
# 306   0.492198  0.984176  9.099525  0.750929  427.212577  0.442653  0.879455
#
#       Diss_sim2  Homogen2    Contrast2  ...   Energy4  Corr4  Diss_sim4  \
# 417   18.174778  0.768723  2052.472456  ...  0.655418      1          0
# 368   13.911067  0.783979  1303.413167  ...  0.551816      1          0
# 1663  26.517910  0.706648  3631.016057  ...  0.627665      1          0
# 703   24.638834  0.723621  3240.182405  ...  0.577401      1          0
# 306   27.304008  0.670964  3251.928668  ...  0.517263      1          0
#
# ...

# %%
y_train.head(5)
# Out:
# 417        English
# 368     Devanagiri
# 1663        Telugu
# 703      Gujarathi
# 306     Devanagiri
# Name: languages, dtype: object

# %% [markdown]
# import plotly.express as px
#
# fig = px.histogram(df, x="languages")
# fig.show()

# %%
df.columns
# Out:
# Index(['Energy', 'Corr', 'Diss_sim', 'Homogen', 'Contrast', 'Energy2', 'Corr2',
#        'Diss_sim2', 'Homogen2', 'Contrast2', 'Energy3', 'Corr3', 'Diss_sim3',
#        'Homogen3', 'Contrast3', 'Energy4', 'Corr4', 'Diss_sim4', 'Homogen4',
#        'Contrast4', 'Energy5', 'Corr5', 'Diss_sim5', 'Homogen5', 'Contrast5',
#        'languages'],
#       dtype='object')

# %%
from pycaret.classification import setup , compare_models
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 from pycaret.classification import setup , compare_models
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pycaret\classification.py:10, in <module>
#       7 import pandas as pd
#       8 import numpy as np
# ---> 10 import pycaret.internal.tabular
#      11 from pycaret.loggers.base_logger import BaseLogger
#      12 from pycaret.parallel import ParallelBackend
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\tabular.py:54, in <module>
#      52 import pycaret.containers.models.clustering
#      53 import pycaret.containers.models.anomaly
# ---> 54 import pycaret.internal.preprocess
#      55 import pandas as pd
#      56 import numpy as np
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\preprocess.py:27, in <module>
# ...

# %%
df.head(5)

# %%
s = setup(data = df,target='languages',fold_shuffle=True)#s = setup(df,target='languages')
# Out:
# <style type="text/css">
# #T_8bda1_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8bda1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bda1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8bda1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bda1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8bda1_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_8bda1_row0_col1" class="data row0 col1" >5568</td>
#     </tr>
#     <tr>
#       <th id="T_8bda1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8bda1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8bda1_row1_col1" class="data row1 col1" >languages</td>
#     </tr>
#     <tr>
#       <th id="T_8bda1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# model training and selection 
compare_models()
# Out:
# <style type="text/css">
# #T_c73ff th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ## Linear Discriminant Analysis is best model

# %% [markdown]
# BEST 3 MODELS
# - LDA
# - GBC
# - LIGHT GBM
